# %% [markdown]
# # Exploratory analysis
# This notebook will be used for initial data inspection and quick plots. Replace placeholders with real data paths and run the preprocessing step first.

# %%
# Import libraries
import pandas as pd
from pathlib import Path
data_path = Path('data/processed/brfss_combined_2011_2023.csv')
if data_path.exists():
    df = pd.read_csv(data_path, comment='#')
    df.head()
else:
    print('Combined data not found. Run src/preprocessing.py --combine or place the combined CSV in data/processed/')
